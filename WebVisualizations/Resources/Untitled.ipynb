# %%
import pandas as pd
import io

# %%
csv_path = "city_data_2020-11-02.csv"
df = pd.read_csv(csv_path)
str_io = io.StringIO()

df.to_html(buf=str_io, classes='table table-striped')

html_str = str_io.getvalue()

print(html_str)
# Out:
# <table border="1" class="dataframe table table-striped">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Long</th>
#       <th>Max Temp (C)</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Windspeed</th>
#       <th>Country Code</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Severo-Kuril'sk</td>
#       <td>50.68</td>
#       <td>156.12</td>
#       <td>6.44</td>
#       <td>83</td>
#       <td>100</td>
#       <td>11.10</td>
#       <td>RU</td>
#       <td>1604350497</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Meulaboh</td>
#       <td>4.14</td>
#       <td>96.13</td>
#       <td>25.07</td>
#       <td>83</td>
#       <td>100</td>
#       <td>2.28</td>
#       <td>ID</td>
#       <td>1604350497</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Vaini</td>
#       <td>-21.20</td>
#       <td>-175.20</td>
# ...

# %%
df
# Out:
#                 City    Lat    Long  Max Temp (C)  Humidity  Cloudiness  \
# 0    Severo-Kuril'sk  50.68  156.12          6.44        83         100
# 1           Meulaboh   4.14   96.13         25.07        83         100
# 2              Vaini -21.20 -175.20         25.00        88          75
# 3      Temascalcingo  19.92 -100.00         24.44        33           3
# 4             Cuamba -14.80   36.54         24.25        62          18
# ..               ...    ...     ...           ...       ...         ...
# 531            Kifrī  34.70   44.97         23.31        22         100
# 532       Sangmélima   2.93   11.98         20.78        94          92
# 533    Sunrise Manor  36.21 -115.07         30.00         8          40
# 534           Katobu  -4.94  122.53         23.88        88         100
# 535    Si Bun Rueang  16.97  102.28         21.60        84          84
#
#      Windspeed Country Code        Date
# 0        11.10           RU  1604350497
# ...

# %%
df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City</th>\n      <th>Lat</th>\n      <th>Long</th>\n      <th>Max Temp (C)</th>\n      <th>Humidity</th>\n      <th>Cloudiness</th>\n      <th>Windspeed</th>\n      <th>Country Code</th>\n      <th>Date</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Severo-Kuril\'sk</td>\n      <td>50.68</td>\n      <td>156.12</td>\n      <td>6.44</td>\n      <td>83</td>\n      <td>100</td>\n      <td>11.10</td>\n      <td>RU</td>\n      <td>1604350497</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Meulaboh</td>\n      <td>4.14</td>\n      <td>96.13</td>\n      <td>25.07</td>\n      <td>83</td>\n      <td>100</td>\n      <td>2.28</td>\n      <td>ID</td>\n      <td>1604350497</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Vaini</td>\n      <td>-21.20</td>\n      <td>-175.20</td>\n      <td>25.00</td>\n      <td>88</td>\n      <td>75</td>\n    
# ...
